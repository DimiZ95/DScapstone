# %% [markdown]
# <h1 align="center"><font size="5">This is a Capstone Project Notebook </fprint("Hello Capstone Project Course!")ont></h1>

# %%
<h1 align="center"><font size="5">This is a Capstone Project Notebook </font></h1>
import numpy as np
import pandas as pd
print("Hello Capstone Project Course!")

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
